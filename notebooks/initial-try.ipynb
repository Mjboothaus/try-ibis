# %%
import ibis

# %%
print(ibis.__version__)
# Out:
# 3.0.2

# %%
SQLITE_HEALTHKIT_DB = "/Users/mjboothaus/code/github/mjboothaus/emmaus-walking-data/data/healthkit_db_2022_06_23.sqlite"

# %%
conn = ibis.sqlite.connect(SQLITE_HEALTHKIT_DB)

# %%
conn.list_tables()
# Out:
# ['activity_summary',
#  'rActiveEnergyBurned',
#  'rAppleExerciseTime',
#  'rAppleStandHour',
#  'rAppleStandTime',
#  'rAppleWalkingSteadiness',
#  'rAudioExposureEvent',
#  'rBasalEnergyBurned',
#  'rBloodPressureDiastolic',
#  'rBloodPressureSystolic',
#  'rBodyMass',
#  'rDistanceCycling',
#  'rDistanceSwimming',
#  'rDistanceWalkingRunning',
#  'rEnvironmentalAudioExposure',
#  'rFlightsClimbed',
#  'rHKDataTypeSleepDurationGoal',
#  'rHeadphoneAudioExposure',
#  'rHeartRate',
#  'rHeartRateVariabilitySDNN',
#  'rHeight',
#  'rMindfulSession',
#  'rOxygenSaturation',
#  'rRespiratoryRate',
#  'rRestingHeartRate',
#  'rSixMinuteWalkTestDistance',
#  'rSleepAnalysis',
#  'rStairAscentSpeed',
#  'rStairDescentSpeed',
#  'rStepCount',
#  'rSwimmingStrokeCount',
#  'rVO2Max',
#  'rWalkingAsymmetryPercentage',
#  'rWalkingDoubleSupportPercentage',
#  'rWalkingHeartRateAverage',
#  'rWalkingSpeed',
#  'rWalkingStepLength',
#  'workout_points',
#  'workouts']

# %%
workouts = conn.table("workouts")

# %%
workouts.execute()
# Out:
#                                            id  \
# 0    4dce6f85f4c5ce9c068a4a60e8f14da6d1a44a2b
# 1    9129c8adef9d8d97a1e95f4fea96c7c2b2c888ba
# 2    b4969cff69d30a35b029c8b69b43ca5be149aa36
# 3    7780f33bce34a79068aa38d01cf5a95ae9f7c7ec
# 4    05abf8e30c86a13386a0b169bb9e0ce7b0c6071d
# ..                                        ...
# 960  89eee294752e609cefd5d7410aa59f781aadce16
# 961  572cd1ff8dd8a9f474193b1e8e7ef52b7535b97b
# 962  213cb4155f1e851c27e486f524b6c75fdbca53ac
# 963  f358092cdbe4bc61fa9edd7e31a620337b04cf69
# 964  edf915078a99caa4afd7af530bbecaea3b7b939c
#
#                     workoutActivityType           duration durationUnit  \
# 0    HKWorkoutActivityTypeCrossTraining  7.883313401540121          min
# 1    HKWorkoutActivityTypeCrossTraining  7.883296998341878          min
# 2    HKWorkoutActivityTypeCrossTraining  7.883283885320028          min
# 3    HKWorkoutActivityTypeCrossTraining  7.882052993774414          min
# 4    HKWorkoutActivityTypeCrossTraining  7.882432158788045          min
# ..                                  ...                ...          ...
# 960        HKWorkoutActivityTypeWalking  12.50705156723658          min
# 961        HKWorkoutActivityTypeWalking   25.1274712006251          min
# 962        HKWorkoutActivityTypeWalking  73.29409403403601          min
# 963        HKWorkoutActivityTypeWalking  16.96465395092964          min
# 964        HKWorkoutActivityTypeWalking  21.86659253438314          min
#
#           totalDistance totalDistanceUnit  totalEnergyBurned  \
# 0                     0                km  533.6471753356659
# 1                     0                km  528.0451984441478
# 2                     0                km  527.3319421829381
# 3                     0                km  527.2449808782145
# 4                     0                km   526.440860621348
# ..                  ...               ...                ...
# 960  0.8575853981041643                km  310.3504216094329
# 961   1.070075435608626                km  398.4322159624801
# 962   5.270266757288423                km   1658.99947564121
# 963   1.206798178412195                km  402.2537863211543
# 964   1.373202305977175                km  434.2409807695947
#
#     totalEnergyBurnedUnit             sourceName sourceVersion  ...  \
# 0                      kJ                  Seven           420  ...
# 1                      kJ                  Seven           420  ...
# 2                      kJ                  Seven           420  ...
# 3                      kJ                  Seven           420  ...
# 4                      kJ                  Seven           420  ...
# ..                    ...                    ...           ...  ...
# 960                    kJ  Michael’s Apple Watch         8.4.2  ...
# 961                    kJ  Michael’s Apple Watch         8.4.2  ...
# 962                    kJ  Michael’s Apple Watch         8.4.2  ...
# 963                    kJ  Michael’s Apple Watch           8.6  ...
# 964                    kJ  Michael’s Apple Watch           8.6  ...
#
#     metadata_HEALTHFIT_MAX_ALTITUDE metadata_HEALTHFIT_FIT_MANUFACTURER  \
# 0                              None                                None
# 1                              None                                None
# 2                              None                                None
# 3                              None                                None
# 4                              None                                None
# ..                              ...                                 ...
# 960                            None                                None
# 961                            None                                None
# 962                            None                                None
# 963                            None                                None
# 964                            None                                None
#
#     metadata_HEALTHFIT_TOTAL_STRIDES metadata_HEALTHFIT_FIT_SERIAL_NUMBER  \
# 0                               None                                 None
# 1                               None                                 None
# 2                               None                                 None
# 3                               None                                 None
# 4                               None                                 None
# ..                               ...                                  ...
# 960                             None                                 None
# 961                             None                                 None
# 962                             None                                 None
# 963                             None                                 None
# 964                             None                                 None
#
#     metadata_HEALTHFIT_SPORT metadata_HKAverageSpeed  \
# 0                       None                    None
# 1                       None                    None
# 2                       None                    None
# 3                       None                    None
# 4                       None                    None
# ..                       ...                     ...
# 960                     None                    None
# 961                     None                    None
# 962                     None                    None
# 963                     None                    None
# 964                     None                    None
#
#     metadata_HEALTHFIT_APP_VERSION metadata_HKExternalUUID  \
# 0                             None                    None
# 1                             None                    None
# 2                             None                    None
# 3                             None                    None
# 4                             None                    None
# ..                             ...                     ...
# 960                           None                    None
# 961                           None                    None
# 962                           None                    None
# 963                           None                    None
# 964                           None                    None
#
#     metadata_HKElevationDescended metadata_HKLapLength
# 0                            None                 None
# 1                            None                 None
# 2                            None                 None
# 3                            None                 None
# 4                            None                 None
# ..                            ...                  ...
# 960                          None                 None
# 961                          None                 None
# 962                          None                 None
# 963                          None                 None
# 964                          None                 None
#
# [965 rows x 48 columns]

# %%
# select
#     id as workout_id,
#     duration as duration_minutes,
#     totaldistance as totaldistance_km,
#     totalenergyburned as totalenergyburned_kJ,
#     sourcename,
#     sourceversion,
#     startdate,
#     enddate,
#     metadata_hkweathertemperature,
#     metadata_hkweatherhumidity,
#     metadata_hkelevationascended,
#     metadata_hkaveragemets
# from
#     workouts
# where workoutactivitytype = "HKWorkoutActivityTypeWalking" or workoutactivitytype = "HKWorkoutActivityTypeHiking" order by id

# %%
workouts.sort_by("id").execute()
# Out:
#                                            id  \
# 0    001f6e971a2088717e108dfeff855cac50dfb999
# 1    00565328016cc4dcb94eba6c0b682c2adce7f63f
# 2    0079b691e400c49f282c9c1b4b7d53322ccf3da4
# 3    00a3955c6416c5241468c359d5a80cfcb29791a4
# 4    0121372783b05b67ef82219fde21347b87636b5b
# ..                                        ...
# 960  fd9c5f614e76df5730f42d3f73563f7147fa7703
# 961  fdfe90ea83809c20d3e962314a2d507f99ed384d
# 962  fe9caca1489f6bb10fd526ccbc6607ea425a6c56
# 963  ff5d2760b41e77dd0df7a0b16fbffcf68b5e0f92
# 964  ffaa60320c2e117a31f74b2938623aa0262a4eb1
#
#                     workoutActivityType           duration durationUnit  \
# 0         HKWorkoutActivityTypeSwimming  23.72831353346507          min
# 1          HKWorkoutActivityTypeWalking  132.2854760666688          min
# 2          HKWorkoutActivityTypeWalking  1409.880814582109          min
# 3          HKWorkoutActivityTypeWalking  141.6858492990335          min
# 4    HKWorkoutActivityTypeCrossTraining  7.883267863591512          min
# ..                                  ...                ...          ...
# 960        HKWorkoutActivityTypeWalking  26.47347821791967          min
# 961        HKWorkoutActivityTypeWalking  22.81444563269615          min
# 962        HKWorkoutActivityTypeWalking  80.28292693297068          min
# 963        HKWorkoutActivityTypeWalking  65.89690608382224          min
# 964        HKWorkoutActivityTypeWalking  221.6405546168486          min
#
#           totalDistance totalDistanceUnit  totalEnergyBurned  \
# 0     0.119684764881992                km   644.202563793023
# 1     8.310377488097933                km  4543.101088774266
# 2     3.728731122359633                km  1028.862503238614
# 3     7.438805077433281                km  3906.228423999998
# 4                     0                km  513.0014753400126
# ..                  ...               ...                ...
# 960   2.173388512836071                km  861.7507472661174
# 961  0.9157054481594823                km  336.9124159999993
# 962   1.708436481574376                km  810.1772079999848
# 963   6.933232854656176                km  2116.020343999995
# 964   14.43368642065767                km  5396.099478871282
#
#     totalEnergyBurnedUnit                         sourceName sourceVersion  \
# 0                      kJ  Michael and Ai Leen’s Apple Watch           6.1
# 1                      kJ  Michael and Ai Leen’s Apple Watch         7.3.1
# 2                      kJ  Michael and Ai Leen’s Apple Watch         5.3.1
# 3                      kJ              Michael’s Apple Watch           8.1
# 4                      kJ                              Seven           420
# ..                    ...                                ...           ...
# 960                    kJ  Michael and Ai Leen’s Apple Watch           8.0
# 961                    kJ  Michael and Ai Leen’s Apple Watch         5.1.1
# 962                    kJ  Michael and Ai Leen’s Apple Watch         3.2.3
# 963                    kJ  Michael and Ai Leen’s Apple Watch         4.3.1
# 964                    kJ  Michael and Ai Leen’s Apple Watch           8.0
#
#      ... metadata_HEALTHFIT_MAX_ALTITUDE metadata_HEALTHFIT_FIT_MANUFACTURER  \
# 0    ...                            None                                None
# 1    ...                            None                                None
# 2    ...                            None                                None
# 3    ...                            None                                None
# 4    ...                            None                                None
# ..   ...                             ...                                 ...
# 960  ...                            None                                None
# 961  ...                            None                                None
# 962  ...                            None                                None
# 963  ...                            None                                None
# 964  ...                            None                                None
#
#     metadata_HEALTHFIT_TOTAL_STRIDES metadata_HEALTHFIT_FIT_SERIAL_NUMBER  \
# 0                               None                                 None
# 1                               None                                 None
# 2                               None                                 None
# 3                               None                                 None
# 4                               None                                 None
# ..                               ...                                  ...
# 960                             None                                 None
# 961                             None                                 None
# 962                             None                                 None
# 963                             None                                 None
# 964                             None                                 None
#
#     metadata_HEALTHFIT_SPORT metadata_HKAverageSpeed  \
# 0                       None                    None
# 1                       None                    None
# 2                       None                    None
# 3                       None                    None
# 4                       None                    None
# ..                       ...                     ...
# 960                     None                    None
# 961                     None                    None
# 962                     None                    None
# 963                     None                    None
# 964                     None                    None
#
#     metadata_HEALTHFIT_APP_VERSION metadata_HKExternalUUID  \
# 0                             None                    None
# 1                             None                    None
# 2                             None                    None
# 3                             None                    None
# 4                             None                    None
# ..                             ...                     ...
# 960                           None                    None
# 961                           None                    None
# 962                           None                    None
# 963                           None                    None
# 964                           None                    None
#
#     metadata_HKElevationDescended metadata_HKLapLength
# 0                            None                 None
# 1                            None                 None
# 2                            None                 None
# 3                            None                 None
# 4                            None                 None
# ..                            ...                  ...
# 960                          None                 None
# 961                          None                 None
# 962                          None                 None
# 963                          None                 None
# 964                          None                 None
#
# [965 rows x 48 columns]

# %%
workout_fields = ["id", "duration"]

# workouts.select("id").name("workout_id")

workouts.select(["id", "duration"]).sort_by("duration").execute()


#   as duration_minutes,
#     totaldistance as totaldistance_km,
#     totalenergyburned as totalenergyburned_kJ,
#     sourcename,
#     sourceversion,
#     startdate,
#     enddate,
#     metadata_hkweathertemperature,
#     metadata_hkweatherhumidity,
#     metadata_hkelevationascended,
#     metadata_hkaveragemets
# Out:
#                                            id           duration
# 0    aebe24cec7a2c4b08ad1fa1188361e90633362fe  1.052748900651932
# 1    0bfc44eb71e5dab9ad97cba041575193571d3f40  1.091906233628591
# 2    df7730b24fd7e7e2c92a7339debed68187b57c77  1.426448883612951
# 3    024aa33aaf0f6023cd9b54e1a2ffa7e9fe27d935  1.598466683427493
# 4    273b6b6bdba0cba1cc028140c66845b98022e6f5  1.998987833658854
# ..                                        ...                ...
# 960  96dc50aa845eb74d9cd712a48e3bbc17d81f717a  97.57144786715507
# 961  499d71fee9a33ebe7f9304b7e894c93b5812696f  97.71967821518579
# 962  79b2847dca69db4fe24b1f378a7338dcc220341c  97.78936993380388
# 963  6d434771ccb77ab7ab63b408eb58482336b87f76  97.93832068443298
# 964  1fc594199bd61eb291ac436987494ec10e65dd35  98.42243951757749
#
# [965 rows x 2 columns]

# %%
print(workouts.select(["id", "duration"]).sort_by("duration").compile())
# Out:
# SELECT t0.id, t0.duration
# FROM (SELECT t1.id AS id, t1.duration AS duration
# FROM main.workouts AS t1) AS t0 ORDER BY t0.duration
